# %%
import neonutilities as nu

# %%
import pandas as pd
import geopandas as gpd
import os
import numpy as np
import glob
import re
import shutil
import laspy
from shapely import geometry

# %%
## Download lidar tiles over plots at each site then subset lidar point cloud for points
# within polygon

# %%
def convert_laz_to_las(in_laz, out_las):
    las = laspy.read(in_laz)
    las = laspy.convert(las)
    las.write(out_las)

# %%
# ---------- Set up workspace and variables ---------- #
product = "DP1.30003.001"
baseplots_fdir = glob.glob(os.path.join("/data/shared/src/arojas/NEON/data/raw/spatial/baseplots","*"))
outdir = "/data/shared/src/arojas/NEON/data/baseplots-lidar"


# for each site
for sitepoly_fdir in baseplots_fdir:
    # Set up workspace, read i polygons
    print(os.path.basename(sitepoly_fdir)[:4])
    siteid = os.path.basename(sitepoly_fdir)[:4]
    site_odir = os.path.join(outdir,siteid)
    if not os.path.isdir(site_odir):
        os.mkdir(site_odir)
    # lets read in plot data!
    sitepoly_fp = glob.glob(os.path.join(sitepoly_fdir, "*.shp"))[0]
    poly_gdf = gpd.read_file(sitepoly_fp)
    
    # list available urls for lidar! (all years available)
    years_list = nu.api.list_available_urls(product,siteid)
    years_list = [os.path.basename(yr)[:-3] for yr in years_list]
    
    # Loop through each year of lidar data, then each plot, and clip
    for yr in years_list:
        # set up year outdir
        siteyr_odir = os.path.join(site_odir,yr)
        if not os.path.isdir(siteyr_odir):
            os.mkdir(siteyr_odir)
        
        # Download las tiles
        nu.api.download_aop_files(product,siteid,yr,
                                  download_folder='./tmp_lidar',
                                  poly=sitepoly_fp)
        # Convert .laz to .las
        for (dirpath, dirnames, filenames) in os.walk('./tmp_lidar'):
            for inFile in filenames:
                if inFile.endswith('.laz'):	
                    in_laz = os.path.join(dirpath,inFile)
                    out_las = in_laz.replace('laz', 'las') 
                    # Convert to las
                    convert_laz_to_las(in_laz, out_las)
        las_fpaths = glob.glob(os.path.join('./tmp_lidar', "*.las"))
        
        # Now go through each .las file and filter for plot data!
        for fpath in las_fpaths:
            # Get file coords
            try:
                coords = re.findall("[0-9]{6}_[0-9]{7}", fpath)[0].split("_")
            except:
                # Not a file with utm coords
                print("Cant find coords!")
                continue
            # Get lower left coords
            x_coord_left = int(coords[0])
            y_coord_bottom = int(coords[1])
            # Get upper right coords
            x_coord_right = x_coord_left + 1000
            y_coord_top = y_coord_bottom + 1000
            # create a shapely polygon
            poly = geometry.Polygon([[x_coord_left, y_coord_bottom], [x_coord_left, y_coord_top],
                                    [x_coord_right,y_coord_top], [x_coord_right, y_coord_bottom]])

            # Read in file, clip for polys!
            las_src = laspy.read(fpath)

            for i in range(len(poly_gdf)):
                # Check for intersection!
                plot_poly = poly_gdf.loc[[i]]
                if plot_poly.intersects(poly).any():
                    # Lets clip!
                    minx, miny, maxx, maxy = plot_poly.bounds.values[0]
                    minx = minx-3
                    miny = miny-3
                    maxx = maxx+3
                    maxy = maxy+3

                    las_dst = laspy.create(point_format=las_src.header.point_format,
                                            file_version=las_src.header.version)
                    # Filter for points!
                    xbool = (las_src.x>=minx) & (las_src.x<=maxx)
                    ybool = (las_src.y>=miny) & (las_src.y<=maxy)
                    las_dst.points = las_src.points[xbool & ybool]
                    plotid = plot_poly['plotID'].values[0]
                    outfp = os.path.join(siteyr_odir,f"{plotid}_lidar_{yr}.las")
                    las_dst.write(outfp)
        # remove tmp_lidar directory
        shutil.rmtree("./tmp_lidar")
# Out:
# ABBY
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/ABBY/2017-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/ABBY/2018-07']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/ABBY/2019-07']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/ABBY/2021-07']
# BARR
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/BARR/2017-07']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/BARR/2018-07']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/BARR/2019-07']
# BART
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/BART/2014-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/BART/2016-08']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/BART/2017-08']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/BART/2018-08']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/BART/2019-08']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/BART/2022-08']
# BLAN
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/BLAN/2016-08']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/BLAN/2017-07']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/BLAN/2019-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/BLAN/2021-08']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/BLAN/2022-05']
# BONA
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/BONA/2017-08']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/BONA/2018-08']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/BONA/2019-08']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/BONA/2021-08']
# CLBJ
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/CLBJ/2016-04']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/CLBJ/2017-05']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/CLBJ/2018-04']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/CLBJ/2019-04']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/CLBJ/2021-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/CLBJ/2022-05']
# CPER
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/CPER/2013-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/CPER/2017-05']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/CPER/2020-06', 'https://data.neonscience.org/api/v0/data/DP1.30003.001/CPER/2020-09']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/CPER/2020-06', 'https://data.neonscience.org/api/v0/data/DP1.30003.001/CPER/2020-09']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/CPER/2021-06']
# DCFS
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/DCFS/2016-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/DCFS/2017-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/DCFS/2019-07']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/DCFS/2020-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/DCFS/2021-06']
# DEJU
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/DEJU/2017-07']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/DEJU/2018-08']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/DEJU/2019-08']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/DEJU/2021-07']
# DELA
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/DELA/2015-07']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/DELA/2016-05']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/DELA/2017-05']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/DELA/2018-04']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/DELA/2019-04']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/DELA/2021-05']
# DSNY
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/DSNY/2014-05']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/DSNY/2016-09']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/DSNY/2017-09']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/DSNY/2018-10']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/DSNY/2019-04']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/DSNY/2021-09']
# GRSM
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/GRSM/2015-08']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/GRSM/2016-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/GRSM/2017-10']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/GRSM/2018-05']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/GRSM/2021-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/GRSM/2022-05']
# GUAN
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/GUAN/2018-05']
# HARV
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/HARV/2014-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/HARV/2016-08']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/HARV/2017-08']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/HARV/2018-09']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/HARV/2019-08']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/HARV/2022-08']
# HEAL
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/HEAL/2017-07']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/HEAL/2018-08']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/HEAL/2019-08']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/HEAL/2021-07']
# JERC
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/JERC/2014-05']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/JERC/2016-09']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/JERC/2017-09']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/JERC/2018-09']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/JERC/2019-09']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/JERC/2021-09']
# JORN
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/JORN/2017-08']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/JORN/2018-08']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/JORN/2019-08']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/JORN/2021-08']
# KONA
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/KONA/2016-07']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/KONA/2017-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/KONA/2018-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/KONA/2019-05', 'https://data.neonscience.org/api/v0/data/DP1.30003.001/KONA/2019-07']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/KONA/2019-05', 'https://data.neonscience.org/api/v0/data/DP1.30003.001/KONA/2019-07']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/KONA/2020-07']
# KONZ
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/KONZ/2016-07']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/KONZ/2017-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/KONZ/2018-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/KONZ/2019-05', 'https://data.neonscience.org/api/v0/data/DP1.30003.001/KONZ/2019-07']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/KONZ/2019-05', 'https://data.neonscience.org/api/v0/data/DP1.30003.001/KONZ/2019-07']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/KONZ/2020-07']
# LAJA
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/LAJA/2018-05']
# LENO
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/LENO/2015-07']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/LENO/2016-05']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/LENO/2017-05']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/LENO/2018-04']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/LENO/2019-05']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/LENO/2021-05']
# MLBS
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/MLBS/2015-08']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/MLBS/2017-08']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/MLBS/2018-05']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/MLBS/2021-06']
# MOAB
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/MOAB/2017-09']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/MOAB/2018-08']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/MOAB/2019-08']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/MOAB/2020-07']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/MOAB/2021-04']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/MOAB/2022-04']
# NIWO
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/NIWO/2017-09']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/NIWO/2018-08']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/NIWO/2019-08']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/NIWO/2020-08']
# NOGP
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/NOGP/2016-07']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/NOGP/2017-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/NOGP/2019-07']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/NOGP/2020-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/NOGP/2021-06']
# OAES
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/OAES/2016-04']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/OAES/2017-05']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/OAES/2018-04']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/OAES/2019-04']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/OAES/2021-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/OAES/2022-05']
# ONAQ
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/ONAQ/2017-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/ONAQ/2019-05']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/ONAQ/2021-05']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/ONAQ/2022-05']
# ORNL
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/ORNL/2015-08']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/ORNL/2016-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/ORNL/2017-09']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/ORNL/2018-05']
# OSBS
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/OSBS/2014-05']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/OSBS/2016-09']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/OSBS/2017-09']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/OSBS/2018-09']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/OSBS/2019-04']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/OSBS/2021-09']
# PUUM
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/PUUM/2019-01']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/PUUM/2020-01']
# RMNP
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/RMNP/2017-07']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/RMNP/2018-09']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/RMNP/2020-07']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/RMNP/2022-07']
# SCBI
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/SCBI/2016-07']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/SCBI/2017-07']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/SCBI/2019-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/SCBI/2021-08']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/SCBI/2022-05']
# SERC
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/SERC/2016-07']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/SERC/2017-07', 'https://data.neonscience.org/api/v0/data/DP1.30003.001/SERC/2017-08']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/SERC/2017-07', 'https://data.neonscience.org/api/v0/data/DP1.30003.001/SERC/2017-08']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/SERC/2019-05']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/SERC/2021-08']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/SERC/2022-05']
# SJER
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/SJER/2013-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/SJER/2017-03']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/SJER/2018-03']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/SJER/2019-03']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/SJER/2021-03']
# SOAP
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/SOAP/2013-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/SOAP/2017-07']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/SOAP/2018-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/SOAP/2019-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/SOAP/2021-07']
# SRER
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/SRER/2017-08']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/SRER/2018-08']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/SRER/2019-09']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/SRER/2021-09']
# STEI
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/STEI/2016-09']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/STEI/2017-08']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/STEI/2019-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/STEI/2020-08']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/STEI/2022-06']
# STER
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/STER/2013-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/STER/2017-07']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/STER/2021-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/STER/2022-07']
# TALL
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/TALL/2015-07']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/TALL/2016-05']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/TALL/2017-05']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/TALL/2018-04']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/TALL/2019-04']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/TALL/2021-05']
# TEAK
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/TEAK/2013-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/TEAK/2017-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/TEAK/2018-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/TEAK/2019-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/TEAK/2021-07']
# TOOL
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/TOOL/2017-07']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/TOOL/2018-07']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/TOOL/2019-07']
# TREE
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/TREE/2016-09']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/TREE/2017-08']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/TREE/2019-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/TREE/2020-08']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/TREE/2022-06']
# UKFS
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/UKFS/2016-07']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/UKFS/2017-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/UKFS/2018-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/UKFS/2019-05']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/UKFS/2020-07']
# UNDE
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/UNDE/2016-09']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/UNDE/2017-09']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/UNDE/2019-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/UNDE/2020-08']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/UNDE/2022-06']
# WOOD
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/WOOD/2016-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/WOOD/2017-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/WOOD/2019-07']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/WOOD/2020-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/WOOD/2021-06']
# WREF
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/WREF/2017-06']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/WREF/2018-07']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/WREF/2019-07']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/WREF/2021-07']
# YELL
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/YELL/2018-07']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/YELL/2019-07']
# ['https://data.neonscience.org/api/v0/data/DP1.30003.001/YELL/2020-07']
