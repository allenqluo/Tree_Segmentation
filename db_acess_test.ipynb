# %%
from sqlalchemy import create_engine, inspect


engine = create_engine('postgresql+psycopg2://cuny:80Fx-reS@localhost:5432/cuny')
inspector = inspect(engine)

for table_name in inspector.get_table_names():
#    for column in inspector.get_columns    (table_name):
#        print("Column: %s" % column['name'])
    print(table_name)
       
       
       
# select c.relname, relkind
# from
#     pg_class c
#     inner join
#     pg_roles r on r.oid = c.relowner
# where
#     r.rolname = 'that_owner'
#     and
#     c.relkind = 'r'
# order by c.relname



# from sqlalchemy import MetaData
# m = MetaData()
# m.reflect(engine)
# for table in m.tables.values():
#     print(table.name)
#     for column in table.c:
#         print(column.name)
# Out:
# ab_permission
# ab_permission_view
# ab_user_role
# ab_permission_view_role
# wb_health_population
# dashboard_slices
# birth_names
# alembic_version
# spatial_ref_sys
# ab_user
# ab_register_user
# ab_view_menu
# ab_role
# url
# css_templates
# favstar
# dashboard_user
# slice_user
# access_request
# logs
# keyvalue
# annotation_layer
# neon_tos_plot_points
# sites
# site_arr
# user_attribute
# annotation
# site_ids
# sqlatable_user
# druiddatasource_user
# tag
# tagged_object
# table_schema
# rls_filter_roles
# rls_filter_tables
# alert_logs
# alert_owner
# sql_observations
# cache_keys
# row_level_security_filters
# tables
# sql_metrics
# clusters
# datasources
# columns
# metrics
# dashboard_email_schedules
# slice_email_schedules
# alerts
# saved_query
# report_recipient
# report_schedule_user
# dynamic_plugin
# dashboard_roles
# tab_state
# report_execution_log
# query
# dbs
# report_schedule
# table_columns
# filter_sets
# slices
# dashboards
# gedi

# %%
import neonutilities
import os

# veg structure product
vegprod = "DP1.10098.001"

# get site
siteid = "TEAK"

url_list = neonutilities.api.list_available_urls("DP1.10098.001",siteid)
# print(url_list)

# Get relative path from this file (wherever the python script is located is the dirname)
dirname = os.path.dirname(__file__)
vegdir = os.path.join(dirname, "data")
if not os.path.exists(vegdir):
    os.makedirs(vegdir)
    
print(vegdir)

# # Lets download data
# neonutilities.api.download_urls(siteurls,download_folder_root=f"{vegdir}/",
#                                 zip=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 27
#      18 url_list = neonutilities.api.list_available_urls("DP1.10098.001",siteid)
#      19 # print(url_list)
#      20
#      21 # if year is None:
#    (...)
#      25
#      26 # Get relative path from this file (wherever the python script is located is the dirname)
# ---> 27 dirname = os.path.dirname(__file__)
#      28 vegdir = os.path.join(dirname, "data")
#      29 if not os.path.exists(vegdir):
#
# NameError: name '__file__' is not defined
